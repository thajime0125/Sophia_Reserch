# %%
import pytesseract
import os
import pandas as pd
import cv2
import matplotlib.pyplot as plt
filedir = "../data/scores/"

# %%
n = 200000
for i in range(0, 260000, 60):
    filepath = f'{filedir}score{i}.jpg'
    if os.path.isfile(filepath):
        img = cv2.imread(filepath)
    if n < i:
        break
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img.shape
# Out:
# (90, 320, 3)

# %%
plt.imshow(cv2.cvtColor(img[48:74, 272:288], cv2.COLOR_BGR2RGB))

# %%
num = pytesseract.image_to_string(img[44:65, 172:186], config='--psm 10')
print(num)
# Out:
# 0
