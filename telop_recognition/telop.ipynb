# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time
filepath = "../game.mp4" # movie file

# %%
def read_movie():
    movie = cv2.VideoCapture(filepath)
    if not movie.isOpened():
        print("can't open")
        exit()
    return movie
target_frame = 2000
movie = read_movie()
for i in range(target_frame):
    ret, frame = movie.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(frame[40:165, 65:250], cv2.COLOR_BGR2RGB))

# %%
cv2.imwrite("score.jpg", frame[40:165, 65:250])
# Out:
# True

# %%
movie = read_movie()
for i in range(target_frame):
    ret, frame = movie.read()
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
